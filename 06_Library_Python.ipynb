# %% [markdown]
# **Part 3: Library For Python**
#
# ---
#
#
# * Pandas: Python Data Analysis
# * NumPy : Numerical Python
# * SciPy : Scientific Python
# * Matplotlib: Plotting library for Python (Data Visualisation with Python)
# * Plotly: Graphing library for Python
# * NumPy and SciPy are both used to make Pandas (Pandas library considered as the most updated one)

# %% [markdown]
# **Part 3.1 : Adding Your Own Data to Python**
#
# ---

# %%
import pandas as pd
''' creating a sample of dataset by using dictionary '''
''' creating a data frame from the dictionary '''
''' keys are the columns and values are data'''

mydata = {
    'Name':['Mohammed','Nurul','Aziz','Fatimah'],
    'Age': [23,32,30,27],
    'City': ['Kuala Lumpur','Kuantan','Shah Alam','Kota Kinabalu'],
    'Salary':[5000,7000,12000,9000]
}

# %%
mydata
# Out:
# {'Name': ['Mohammed', 'Nurul', 'Aziz', 'Fatimah'],
#  'Age': [23, 32, 30, 27],
#  'City': ['Kuala Lumpur', 'Kuantan', 'Shah Alam', 'Kota Kinabalu'],
#  'Salary': [5000, 7000, 12000, 9000]}

# %%
type(mydata)
# Out:
# dict

# %% [markdown]
# **Part 3.2: DataFrame**
#
# ---

# %%
#convert dictionary to data frame
df = pd.DataFrame(mydata)
df.head()
# Out:
#        Name  Age           City  Salary
# 0  Mohammed   23   Kuala Lumpur    5000
# 1     Nurul   32        Kuantan    7000
# 2      Aziz   30      Shah Alam   12000
# 3   Fatimah   27  Kota Kinabalu    9000

# %% [markdown]
# * columns = features or attributes
# * rows = cases
# * Note: Later on we will practice concatenate data; which is combining items and addding rows

# %%
data1 = {
    'A':['A1', 'A2', 'A3', 'A4'],
    'B':['B1', 'B2', 'B3', 'B4'],
    'C':['C1', 'C2', 'C3', 'C4'],
    'D':['D1', 'D2', 'D3', 'D4']
}

data2 = {
    'A':['A5', 'A6', 'A7', 'A8'],
    'B':['B5', 'B6', 'B7', 'B8'],
    'C':['C5', 'C6', 'C7', 'C8'],
    'D':['D5', 'D6', 'D7', 'D8']
}

# %% [markdown]
# Note: pandas will always read the data into a dataframe once you use pandas the data will always converted into dataframe
#
# when you use machine learning, we have to convert back the dataframe into arrays or list

# %%
data1_df = pd.DataFrame(data1)
data2_df = pd.DataFrame(data2)

# %%
data1_df.head()
# Out:
#     A   B   C   D
# 0  A1  B1  C1  D1
# 1  A2  B2  C2  D2
# 2  A3  B3  C3  D3
# 3  A4  B4  C4  D4

# %%
data2_df.head()
# Out:
#     A   B   C   D
# 0  A5  B5  C5  D5
# 1  A6  B6  C6  D6
# 2  A7  B7  C7  D7
# 3  A8  B8  C8  D8

# %% [markdown]
# **Part 3.3: Concatenate & Reseting Index**
#
# ---
#
#
# Part 3.3.1: Concatenate rows

# %%
#Concatenate data ## refer back to this section later ##

df_data1_data2 = [data1_df, data2_df]
df_1_2 = pd.concat(df_data1_data2)
df_1_2.head(8)
# Out:
#     A   B   C   D
# 0  A1  B1  C1  D1
# 1  A2  B2  C2  D2
# 2  A3  B3  C3  D3
# 3  A4  B4  C4  D4
# 0  A5  B5  C5  D5
# 1  A6  B6  C6  D6
# 2  A7  B7  C7  D7
# 3  A8  B8  C8  D8

# %% [markdown]
# Notice how the index of the row is 0,1,2,3,0,1,2,3?
#
# *So now we have to reset the index

# %% [markdown]
# **Part 3.3.2: Reseting The Index**

# %%
#index reseting
df_1_2 = df_1_2.reset_index()

# %% [markdown]
# Note: Notice that now you will have 2 index in the table below

# %%
df_1_2.head(8)
# Out:
#    index   A   B   C   D
# 0      0  A1  B1  C1  D1
# 1      1  A2  B2  C2  D2
# 2      2  A3  B3  C3  D3
# 3      3  A4  B4  C4  D4
# 4      0  A5  B5  C5  D5
# 5      1  A6  B6  C6  D6
# 6      2  A7  B7  C7  D7
# 7      3  A8  B8  C8  D8

# %%
#index reseting
df_1_2 = df_1_2.reset_index(drop=True) ##now we going to use some parameters (it will always be False)
df_1_2.head(8)

#Refer back to "concatenate data" code section above
#Then refresh this data to get the desired result
# Out:
#    index   A   B   C   D
# 0      0  A1  B1  C1  D1
# 1      1  A2  B2  C2  D2
# 2      2  A3  B3  C3  D3
# 3      3  A4  B4  C4  D4
# 4      0  A5  B5  C5  D5
# 5      1  A6  B6  C6  D6
# 6      2  A7  B7  C7  D7
# 7      3  A8  B8  C8  D8

# %%
data3 = {
    'E':['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8'],
    'F':['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8'],
}

df_data3 = pd.DataFrame(data3)
df_data3.head(8)
# Out:
#     E   F
# 0  E1  F1
# 1  E2  F2
# 2  E3  F3
# 3  E4  F4
# 4  E5  F5
# 5  E6  F6
# 6  E7  F7
# 7  E8  F8

# %% [markdown]
# **Part 3.3.3: Concatenate Column**

# %%
df_all = [df_1_2, df_data3]
df_all = pd.concat(df_all, axis =1) #to concatenate column, we must mention axis = 1, if not mention it will concatenate
df_all.head(8)
# Out:
#    index   A   B   C   D   E   F
# 0      0  A1  B1  C1  D1  E1  F1
# 1      1  A2  B2  C2  D2  E2  F2
# 2      2  A3  B3  C3  D3  E3  F3
# 3      3  A4  B4  C4  D4  E4  F4
# 4      0  A5  B5  C5  D5  E5  F5
# 5      1  A6  B6  C6  D6  E6  F6
# 6      2  A7  B7  C7  D7  E7  F7
# 7      3  A8  B8  C8  D8  E8  F8

# %%
df_all.shape
# Out:
# (8, 7)

# %% [markdown]
# **Exercise:**
#
# ---
#
#
# create your own datasets, concatenate in terms of rows once, and in terms of columns once again

# %%
#create your own datasets, concatenate in terms of rows once, and in terms of columns once again

df = pd.read_csv('NFLX.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
df.shape
# Out:
# (1007, 7)

# %%
df1 = pd.read_csv('custcat.csv')
df1.head()
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
df1.shape
# Out:
# (1000, 12)

# %%
#concatenate rows from the two datasets

df2 = [df, df1]
dfNC = pd.concat(df2)
dfNC.head(42)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1   2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2   2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3   2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4   2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
# 5   2015-12-23  116.910004  118.559998  115.779999  118.160004  118.160004
# 6   2015-12-24  118.220001  118.800003  117.300003  117.330002  117.330002
# 7   2015-12-28  117.260002  117.349998  113.849998  117.110001  117.110001
# 8   2015-12-29  118.190002  119.599998  116.919998  119.120003  119.120003
# 9   2015-12-30  118.949997  119.019997  116.430000  116.709999  116.709999
# 10  2015-12-31  116.209999  117.459999  114.279999  114.379997  114.379997
# 11  2016-01-04  109.000000  110.000000  105.209999  109.959999  109.959999
# 12  2016-01-05  110.449997  110.580002  105.849998  107.660004  107.660004
# 13  2016-01-06  105.290001  117.910004  104.959999  117.680000  117.680000
# 14  2016-01-07  116.360001  122.180000  112.290001  114.559998  114.559998
# 15  2016-01-08  116.330002  117.720001  111.099998  111.389999  111.389999
# 16  2016-01-11  112.129997  116.790001  111.199997  114.970001  114.970001
# 17  2016-01-12  116.110001  117.779999  115.080002  116.580002  116.580002
# 18  2016-01-13  114.430000  114.480003  104.529999  106.559998  106.559998
# 19  2016-01-14  105.650002  109.250000  101.209999  107.059998  107.059998
# 20  2016-01-15  102.430000  105.500000  101.720001  104.040001  104.040001
# 21  2016-01-19  106.570000  110.139999  105.550003  107.889999  107.889999
# 22  2016-01-20  108.910004  109.989998   97.050003  107.739998  107.739998
# 23  2016-01-21  108.320000  108.510002  102.099998  102.349998  102.349998
# 24  2016-01-22  104.720001  104.989998   99.220001  100.720001  100.720001
# 25  2016-01-25   99.779999  102.680000   99.000000   99.120003   99.120003
# 26  2016-01-26   99.739998  100.550003   94.849998   97.830002   97.830002
# 27  2016-01-27   96.610001   97.849998   90.589996   91.150002   91.150002
# 28  2016-01-28   93.839996   95.250000   90.110001   94.410004   94.410004
# 29  2016-01-29   92.000000   94.389999   90.629997   91.839996   91.839996
# 30  2016-02-01   91.790001   97.180000   91.300003   94.089996   94.089996
# 31  2016-02-02   95.540001   96.650002   90.730003   91.489998   91.489998
# 32  2016-02-03   92.410004   92.690002   86.139999   90.739998   90.739998
# 33  2016-02-04   89.500000   91.250000   86.540001   89.709999   89.709999
# 34  2016-02-05   88.230003   88.949997   81.860001   82.790001   82.790001
# 35  2016-02-08   80.570000   84.699997   79.949997   83.320000   83.320000
# 36  2016-02-09   81.750000   88.400002   81.550003   86.129997   86.129997
# 37  2016-02-10   89.000000   92.209999   87.419998   88.449997   88.449997
# 38  2016-02-11   87.419998   88.389999   82.910004   86.349998   86.349998
# 39  2016-02-12   86.639999   89.720001   85.260002   87.400002   87.400002
# 40  2016-02-16   89.000000   90.139999   87.540001   89.050003   89.050003
# 41  2016-02-17   90.129997   94.769997   89.639999   94.760002   94.760002
#
#         Volume  region  tenure  age  marital  address  income  ed  employ  \
# 0   13181000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 1   17284900.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 2   17948100.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 3   11670000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 4    9689000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 5    9324300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 6    3531300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 7    8424300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 8    8159200.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 9    8149700.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 10   9273000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 11  20794800.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 12  17664600.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 13  33045700.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 14  33636700.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 15  18067100.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 16  21920400.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 17  15133500.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 18  24921600.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 19  23664800.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 20  19775100.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 21  35722800.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 22  53009400.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 23  31027500.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 24  26821800.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 25  20321100.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 26  22083900.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 27  25556200.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 28  24562300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 29  20463900.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 30  19684500.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 31  21906500.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 32  27466000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 33  19108600.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 34  25929300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 35  25035600.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 36  25892900.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 37  23146500.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 38  21820300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 39  19067700.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 40  16356600.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 41  18323800.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
#
#     retire  gender  reside  custcat
# 0      NaN     NaN     NaN      NaN
# 1      NaN     NaN     NaN      NaN
# 2      NaN     NaN     NaN      NaN
# 3      NaN     NaN     NaN      NaN
# 4      NaN     NaN     NaN      NaN
# 5      NaN     NaN     NaN      NaN
# 6      NaN     NaN     NaN      NaN
# 7      NaN     NaN     NaN      NaN
# 8      NaN     NaN     NaN      NaN
# 9      NaN     NaN     NaN      NaN
# 10     NaN     NaN     NaN      NaN
# 11     NaN     NaN     NaN      NaN
# 12     NaN     NaN     NaN      NaN
# 13     NaN     NaN     NaN      NaN
# 14     NaN     NaN     NaN      NaN
# 15     NaN     NaN     NaN      NaN
# 16     NaN     NaN     NaN      NaN
# 17     NaN     NaN     NaN      NaN
# 18     NaN     NaN     NaN      NaN
# 19     NaN     NaN     NaN      NaN
# 20     NaN     NaN     NaN      NaN
# 21     NaN     NaN     NaN      NaN
# 22     NaN     NaN     NaN      NaN
# 23     NaN     NaN     NaN      NaN
# 24     NaN     NaN     NaN      NaN
# 25     NaN     NaN     NaN      NaN
# 26     NaN     NaN     NaN      NaN
# 27     NaN     NaN     NaN      NaN
# 28     NaN     NaN     NaN      NaN
# 29     NaN     NaN     NaN      NaN
# 30     NaN     NaN     NaN      NaN
# 31     NaN     NaN     NaN      NaN
# 32     NaN     NaN     NaN      NaN
# 33     NaN     NaN     NaN      NaN
# 34     NaN     NaN     NaN      NaN
# 35     NaN     NaN     NaN      NaN
# 36     NaN     NaN     NaN      NaN
# 37     NaN     NaN     NaN      NaN
# 38     NaN     NaN     NaN      NaN
# 39     NaN     NaN     NaN      NaN
# 40     NaN     NaN     NaN      NaN
# 41     NaN     NaN     NaN      NaN

# %%
dfNC.shape
# Out:
# (2007, 19)

# %%
#reset index
dfNC = dfNC.reset_index(drop=True)
dfNC.head(11)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1   2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2   2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3   2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4   2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
# 5   2015-12-23  116.910004  118.559998  115.779999  118.160004  118.160004
# 6   2015-12-24  118.220001  118.800003  117.300003  117.330002  117.330002
# 7   2015-12-28  117.260002  117.349998  113.849998  117.110001  117.110001
# 8   2015-12-29  118.190002  119.599998  116.919998  119.120003  119.120003
# 9   2015-12-30  118.949997  119.019997  116.430000  116.709999  116.709999
# 10  2015-12-31  116.209999  117.459999  114.279999  114.379997  114.379997
#
#         Volume  region  tenure  age  marital  address  income  ed  employ  \
# 0   13181000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 1   17284900.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 2   17948100.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 3   11670000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 4    9689000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 5    9324300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 6    3531300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 7    8424300.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 8    8159200.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 9    8149700.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
# 10   9273000.0     NaN     NaN  NaN      NaN      NaN     NaN NaN     NaN
#
#     retire  gender  reside  custcat
# 0      NaN     NaN     NaN      NaN
# 1      NaN     NaN     NaN      NaN
# 2      NaN     NaN     NaN      NaN
# 3      NaN     NaN     NaN      NaN
# 4      NaN     NaN     NaN      NaN
# 5      NaN     NaN     NaN      NaN
# 6      NaN     NaN     NaN      NaN
# 7      NaN     NaN     NaN      NaN
# 8      NaN     NaN     NaN      NaN
# 9      NaN     NaN     NaN      NaN
# 10     NaN     NaN     NaN      NaN

# %% [markdown]
# **Part 3.4: Exploring Random Rows**
#
# ---

# %%
df = pd.read_csv('NFLX.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
#Random chosen row
df.sample()
# Out:
#            Date   Open        High         Low       Close   Adj Close  \
# 637  2018-06-28  395.0  396.899994  387.100006  395.420013  395.420013
#
#        Volume
# 637  12219900

# %%
df.shape
# Out:
# (1007, 7)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1007, step=1)

# %% [markdown]
# **Checking Columns Name:**
#
# ---
#
#
#
# Pandas Data type:
#
# * Str - object
# * Int -Int32, int64
# * float - float32, int64

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1007.000000  1007.000000  1007.000000  1007.000000  1007.000000
# mean    226.708094   229.972979   223.105690   226.670159   226.670159
# std     103.305422   104.851349   101.458611   103.203785   103.203785
# min      80.570000    84.699997    79.949997    82.790001    82.790001
# 25%     125.779999   127.165001   124.355000   125.514999   125.514999
# 50%     197.850006   199.440002   195.330002   198.000000   198.000000
# 75%     325.529999   330.835006   318.869995   325.220001   325.220001
# max     421.380005   423.209991   413.079987   418.970001   418.970001
#
#              Volume
# count  1.007000e+03
# mean   9.730586e+06
# std    6.398967e+06
# min    1.616300e+06
# 25%    5.573200e+06
# 50%    7.857600e+06
# 75%    1.178630e+07
# max    5.841040e+07

# %% [markdown]
# * std = Standard deviation (normal distribution) <-- standard deviation is just about distribution
# * mean - measure central tendency

# %% [markdown]
# **Part 3.5: Making A Copy Of The Data**
#
# ---

# %%
df2 = df.copy()
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %% [markdown]
# Calculating value of a specific column

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df['High'].mean()
# Out:
# 229.97297904468715

# %%
df['Low'].std()
# Out:
# 101.45861102484218

# %%
df['Close'].max()
# Out:
# 418.970001

# %%
df['Close'].min()
# Out:
# 82.790001

# %% [markdown]
# **Part 3.6: Index Slicing**
#
# ---
#
#
# * Call Cells
#
# * call specific cell from the dataframe
#
#   * iloc
#   * loc

# %% [markdown]
# **NOTE: Jangan lupa kira 'Data' index 0, 'Open' index 1 etc..**
#
# **iloc Function**
#
# ---
#
#
#
# * iloc: This is an integer-based indexing method in Pandas.
#
# * It is used for selecting data by position or integer index.
#
# * It allows you to select data by row numbers and column numbers (integer position).
#
# * For example, df.iloc[row_index, column_index] selects data at the specified row and column indices.

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
#df.iloc[row index,column index]

df.iloc[2,3]
# Out:
# 117.919998

# %%
df.iloc[0:5,2:4]
# Out:
#          High         Low
# 0  123.000000  118.089996
# 1  126.349998  122.419998
# 2  122.190002  117.919998
# 3  119.589996  115.660004
# 4  117.430000  114.860001

# %% [markdown]
# **Loc Function - will only give output of index of the row and name of column**
#
# * loc: This is a label-based indexing method in Pandas.
#
# * It is used to access a group of rows and columns by labels or a boolean array.
#
# * It allows you to select data by row labels and column labels.
#
# * For example, df.loc[row_label, column_label] selects data at the specified row and column labels.

# %%
#df.loc[[row index],[column name]]
df.loc[[2],['High']]
# Out:
#          High
# 2  122.190002

# %% [markdown]
# **Part 3.7: Selecting specific column and defined into new dataframe**
#
# ---

# %%
df3 = df.iloc[:,0:3]
df3.head()
# Out:
#          Date        Open        High
# 0  2015-12-16  119.800003  123.000000
# 1  2015-12-17  123.970001  126.349998
# 2  2015-12-18  120.849998  122.190002
# 3  2015-12-21  119.510002  119.589996
# 4  2015-12-22  117.300003  117.430000

# %% [markdown]
# **Part 3.8: Checking the Data Info**
#
# ---
#
#
# Can tell us if there is any null / missing value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1007 non-null   object
#  1   Open       1007 non-null   float64
#  2   High       1007 non-null   float64
#  3   Low        1007 non-null   float64
#  4   Close      1007 non-null   float64
#  5   Adj Close  1007 non-null   float64
#  6   Volume     1007 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.2+ KB

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# **Part 3.9: Rename Column**
#
# ---
#
#
# * The inplace=True parameter in Python, particularly in Pandas DataFrame operations, specifies whether to modify the DataFrame directly or return a new modified copy of the DataFrame. Here’s how it works:
#
# inplace=True
#
# * When inplace=True is used in a Pandas operation (e.g., .drop() or .fillna()), it modifies the DataFrame directly.
# * This means that the changes are applied to the original DataFrame itself, and the operation does not return a new DataFrame.
#
#
# inplace=False
#
# * When inplace=False or if inplace is not specified (which defaults to False), the operation returns a new modified DataFrame without affecting the original DataFrame.
# * This allows you to chain operations or keep the original DataFrame intact.

# %%
df.rename(columns = {'High': 'Test'}, inplace = True) #Kalau kita letak 'inplace = true' dia akan kacau original data
df.head()
# Out:
#          Date        Open        Test         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
df_test = df.rename(columns = {'Low': 'Test'})
df_test.head()
# Out:
#          Date        Open        Test        Test       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000
