# %% [markdown]
# **Numpy & Matplot Libraries**
#
# ---
#
#
#
# * Part 1: Create a Sample Dataset With Various Datatype Using Numpy
#   * Part 1.1: np. random Function
#   * Part 1.2: Mean, Standard Deviation, Data Sample
#   * Part 1.3: Rename The Column Index
#   * Part 1.4: Wrong Data Type
#   * Part 1.5: Labelling The Right Data Type
#
#
#
# * Exercise: Create Your Own Dataset Using NumPy
#
#
# * Part 2: Matplot Libary
#   * Part 2.1: How To Add Labels
#   * Part 2.2: How To Add Title
#   * Part 2.3: How To Add Legend
#   * Part 2.4: How to Customize The Line
#     * 2.4.1: Changing Colour of The Line
#     * 2.4.2: Dash line
#     * 2.4.3: Adding Marker (The Markert (dots) in the line)
#     * 2.4.4: Changing the thickness of the line
#   * Part 2.5: Adding A Grid To The Background
#   * Part 2.6: Checking All Available Style in Matplot Library
#
#
# * Exercise : Testing Matplot Library Cheat Sheet

# %% [markdown]
# **Part 1: Create A Sample Dataset With Various Datatypes Using Numpy**
#
#
# ---
#
# **Part 1.1: np. random Function**
#
#
# * Types of data (numerical, categorical, and datetime)
#
#
# * Difference Between np.linspace (refer previous note 5) and np.random function
#
# * numpy.linspace (np.linspace)
#
# * Purpose: To generate evenly spaced numbers over a specified range.
#
# * Usage: numpy.linspace(start, stop, num)
#
# * Parameters:
#
# * start: The starting value of the sequence.
# * stop: The end value of the sequence.
# * num: The number of samples to generate (including the start and stop values).
#   numpy.random (np.random)
#
# * Purpose: To generate random numbers.
# * Usage: numpy.random provides several methods to generate random numbers, including:
# * numpy.random.rand(d0, d1, ..., dn): Uniform distribution over [0, 1).
# * numpy.random.randn(d0, d1, ..., dn): Standard normal distribution (mean 0, variance 1).
# * numpy.random.randint(low, high=None, size=None, dtype='l'): Random integers * * from low (inclusive) to high (exclusive).
# * numpy.random.normal(loc=0.0, scale=1.0, size=None): Normal (Gaussian) distribution. And many others.
#
#
# * Summary
#
#   * numpy.linspace: Generates a specified number of evenly spaced values over a given range. Useful for deterministic sequences where the exact values and their spacing are important.
#   * numpy.random: Generates random numbers from various distributions. Useful for creating random samples, simulations, or any situation where randomness is required.

# %% [markdown]
# **Part 1.2: Mean, Standard Deviation, Data Sample**
#
#
# ---
#
#
# ![image.png](data:image/png;base64,...)
#
#
# * Refer code below: In the code "col1 = np.random.normal(250, 10, 500)", the parameters 250, 10, and 500 represent the following:
#
# * 250: This is the mean (average) of the normal distribution. It determines the center of the distribution.
#
# * 10: This is the standard deviation of the normal distribution. It measures the spread or dispersion of the data around the mean. A smaller standard deviation means the data points are closer to the mean, while a larger standard deviation means they are more spread out.
#
# * 500: This is the number of samples to be generated from the normal distribution. It specifies how many data points will be created.
#
# * In summary, np.random.normal(250, 10, 500) generates 500 random samples from a normal distribution with a mean of 250 and a standard deviation of 10.

# %% [markdown]
# **Now We Are Creating A Sample Data Using Various Types of data (Numerical, Categorical, and Datetime**

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

#create numerical data (or numerical column)
#all those column that will be int or float

col1 = np.random.normal(250, 10, 500) #(mean,std,number of samples)
col2 = np.random.normal(100, 20, 500)
col3 = np.random.normal(750, 5, 500)

#create categorical data

categorical_data = ['A','B','C','D','F','G','H','I','J']

col4 = np.random.choice(categorical_data, 500)
col5 = np.random.choice(categorical_data, 500) #use np.random.choice for categorical data

#create data time

start_date = datetime(2022, 1, 1)
end_date = datetime(2024, 1, 1)

delta = end_date - start_date

date_list = [start_date + timedelta(days=x) for x in range(delta.days)]

col6 = np.random.choice(date_list, 500)

#combine all the columns

data = np.column_stack((col1,col2,col3,col4,col5,col6))

df = pd.DataFrame(data)
df.head()
# Out:
#             0           1           2  3  4          5
# 0  248.253376   78.341104   761.04901  I  D 2023-09-16
# 1  255.944791  103.008277  756.631535  I  H 2022-07-25
# 2  240.165467  117.645977   751.15819  C  J 2022-11-08
# 3  234.895479   83.190631  752.516415  A  I 2023-09-14
# 4  244.913234    95.64243  742.035847  A  B 2023-09-29

# %% [markdown]
# **Part 1.3: Rename The Column Index**
#
# ---
#
#
# * Notice how the columns above named " 0, 1, 2, 3, 4, 5"
#
#
# * We will now rename those columns

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

#create numerical data (or numerical column)
#all those column that will be int or float

col1 = np.random.normal(250, 10, 500)
col2 = np.random.normal(100, 20, 500)
col3 = np.random.normal(750, 5, 500)

#create categorical data

categorical_data = ['A','B','C','D','F','G','H','I','J']

col4 = np.random.choice(categorical_data, 500)
col5 = np.random.choice(categorical_data, 500)

#create data time

start_data = datetime(2022, 1, 1) # This variable was originally named 'start_data'
end_date = datetime(2024, 1, 1)

# Use 'start_data' instead of 'start_date'
delta = end_date - start_data

date_list = [start_data + timedelta(days=x) for x in range(delta.days)]

col6 = np.random.choice(date_list, 500)

#combine all the columns

data = np.column_stack((col1,col2,col3,col4,col5,col6))

# Rename the columns
df = pd.DataFrame(data, columns =['Num1','Num2','Num3','Cat1','Cat2','Date'])
df.head() # Call the head() method to display the DataFrame
# Out:
#          Num1        Num2        Num3 Cat1 Cat2       Date
# 0  246.107473   96.760184  752.979163    J    G 2022-08-09
# 1  256.606224  145.663897  745.760175    A    A 2023-09-15
# 2  248.437038   83.918248  743.820431    C    C 2023-11-02
# 3  255.290291  101.647376  754.142609    F    I 2023-04-04
# 4  249.639622  104.395454  751.961187    J    F 2022-11-07

# %%
df.shape
# Out:
# (500, 6)

# %% [markdown]
# **Part 1.4: Wrong Data Type**
#
# ---
#
#
# * You will notice that 'num1' num2' 'num3' is considered "object" not float
# * So it's normal for Python to labelled the datatype wrongly, so we have to fix it!

# %%
df.info()
# you will notice that 'num1-3' is considered object not float (so it's normal that data labelled wrong data type, so we have to fix it)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Num1    500 non-null    object
#  1   Num2    500 non-null    object
#  2   Num3    500 non-null    object
#  3   Cat1    500 non-null    object
#  4   Cat2    500 non-null    object
#  5   Date    500 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 23.6+ KB

# %%
df.describe()
#This will only describe numerical datatype
# Out:
#                              Date
# count                         500
# mean   2023-01-02 06:20:09.600000
# min           2022-01-01 00:00:00
# 25%           2022-07-11 18:00:00
# 50%           2023-01-07 00:00:00
# 75%           2023-06-23 12:00:00
# max           2023-12-31 00:00:00

# %%
df.describe(include='all')
# (include='all) will describe all categorical and numerical datatype
# NaN = Not A Number
# Out:
#               Num1        Num2        Num3 Cat1 Cat2  \
# count   500.000000  500.000000  500.000000  500  500
# unique  500.000000  500.000000  500.000000    9    9
# top     246.107473   96.760184  752.979163    I    H
# freq      1.000000    1.000000    1.000000   68   62
# mean           NaN         NaN         NaN  NaN  NaN
# min            NaN         NaN         NaN  NaN  NaN
# 25%            NaN         NaN         NaN  NaN  NaN
# 50%            NaN         NaN         NaN  NaN  NaN
# 75%            NaN         NaN         NaN  NaN  NaN
# max            NaN         NaN         NaN  NaN  NaN
#
#                               Date
# count                          500
# unique                         NaN
# top                            NaN
# freq                           NaN
# mean    2023-01-02 06:20:09.600000
# min            2022-01-01 00:00:00
# 25%            2022-07-11 18:00:00
# 50%            2023-01-07 00:00:00
# 75%            2023-06-23 12:00:00
# max            2023-12-31 00:00:00

# %% [markdown]
# **Part 1.5: Labelling The Right Data Type**
#
# ---
#
#
# * Converting object datatype to float/interger

# %%
#Changing one:
df['Num1'] = df['Num1'].astype(float)

#Changing multiple at once:
df[['Num2','Num3']] = df[['Num2','Num3']].astype(float)

df.dtypes #ways to check the datatype
# Out:
# Num1           float64
# Num2           float64
# Num3           float64
# Cat1            object
# Cat2            object
# Date    datetime64[ns]
# dtype: object

# %%
df.head(20)
# Out:
#           Num1        Num2        Num3 Cat1 Cat2       Date
# 0   246.107473   96.760184  752.979163    J    G 2022-08-09
# 1   256.606224  145.663897  745.760175    A    A 2023-09-15
# 2   248.437038   83.918248  743.820431    C    C 2023-11-02
# 3   255.290291  101.647376  754.142609    F    I 2023-04-04
# 4   249.639622  104.395454  751.961187    J    F 2022-11-07
# 5   263.878960  116.983855  753.553435    D    D 2023-07-13
# 6   247.651585  103.612406  751.490873    G    G 2022-11-17
# 7   253.420072   91.393409  742.392167    A    F 2023-12-28
# 8   246.460773   57.952584  753.163046    D    J 2023-10-18
# 9   249.718075   74.609371  751.330137    I    D 2022-11-17
# 10  252.597698  136.877977  746.751634    I    I 2022-11-04
# 11  254.588716  120.733093  736.788107    J    B 2022-02-11
# 12  234.217060  102.579897  750.693703    H    I 2022-01-15
# 13  263.879870   63.329453  753.712012    B    J 2023-07-28
# 14  248.617523   60.787812  755.028209    C    F 2022-08-21
# 15  240.669819  133.978142  749.188573    D    J 2022-12-14
# 16  249.514049  112.954805  756.573222    I    A 2022-12-16
# 17  264.250558  113.692279  758.920358    C    G 2022-02-12
# 18  251.358397  101.297216  751.323592    G    J 2022-03-26
# 19  245.279409  124.069710  744.598119    F    J 2023-10-28

# %% [markdown]
# **Exercise; Create Your Own Dataset Using Numpy**
#
# ---
#
#
# Test 1

# %%
#TEST 1

import pandas as pd
import numpy as np
from datetime import datetime, timedelta

#create numerical data (or numerical column)
#all those column that will be int or float

col7 = np.random.normal(500, 20, 500)
col8 = np.random.normal(100, 10, 500)
col9 = np.random.normal(950, 7, 500)

#create categorical data

categorical_data = ['Amy','Sya','Naquibah','Zura','Abidah','Saras','Nabila','Aisyah','Maryam','Anis','Hikmah']

col10 = np.random.choice(categorical_data, 500)
col11 = np.random.choice(categorical_data, 500)

#create data time

start_data = datetime(2023, 1, 1) # This variable was originally named 'start_data'
end_date = datetime(2024, 1, 1)

# Use 'start_data' instead of 'start_date'
delta = end_date - start_data

date_list = [start_data + timedelta(days=x) for x in range(delta.days)]

col12 = np.random.choice(date_list, 500)

#combine all the columns

data = np.column_stack((col7,col8,col9,col10,col11,col12))

df_T1 = pd.DataFrame(data, columns =['Num1','Num2','Num3','Name','Name2','Date'])
df_T1.head(20) # Call the head() method to display the DataFrame
# Out:
#           Num1        Num2        Num3      Name   Name2       Date
# 0   545.521388   99.483191  958.883378    Aisyah  Maryam 2023-04-09
# 1   486.199394  111.964331  941.380852    Abidah   Saras 2023-10-05
# 2   479.193577  111.222809  957.592549      Zura  Abidah 2023-01-07
# 3   533.481854  103.700175  975.627096      Zura  Hikmah 2023-04-27
# 4   527.699026   85.670796  957.179533  Naquibah     Sya 2023-08-30
# 5   519.287995  107.821566  956.339521    Hikmah  Aisyah 2023-07-13
# 6   515.620832  129.334943  943.043715  Naquibah    Zura 2023-12-08
# 7   509.742537   98.703883  949.315815    Maryam  Abidah 2023-01-01
# 8   513.077922  105.963277  944.905203    Aisyah    Anis 2023-03-24
# 9   528.907083  103.544479  961.709649    Aisyah   Saras 2023-11-26
# 10  508.903956    90.30072  957.934833    Aisyah   Saras 2023-01-08
# 11  472.186839   97.278174  941.292693       Sya     Sya 2023-12-19
# 12  483.539142  111.765024  951.614317      Anis     Sya 2023-03-27
# 13  501.604396   95.844151  945.290343       Sya     Sya 2023-04-21
# 14  498.589306  108.478073  946.176413    Nabila  Aisyah 2023-10-17
# 15  488.325204  108.904014  957.761656    Maryam     Amy 2023-01-24
# 16   501.08359  113.648948  950.917419    Aisyah   Saras 2023-11-29
# 17  492.660067   106.42445  944.424552    Aisyah  Abidah 2023-10-03
# 18  510.457324   76.110671   947.81097      Zura     Amy 2023-09-16
# 19  530.227418  127.670199  954.072206    Maryam    Anis 2023-03-23

# %%
df_T1.describe()
# Out:
#                                 Date
# count                            500
# mean   2023-06-29 17:59:59.999999744
# min              2023-01-01 00:00:00
# 25%              2023-03-22 18:00:00
# 50%              2023-06-30 12:00:00
# 75%              2023-10-03 06:00:00
# max              2023-12-30 00:00:00

# %%
df_T1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Num1    500 non-null    object
#  1   Num2    500 non-null    object
#  2   Num3    500 non-null    object
#  3   Name    500 non-null    object
#  4   Name2   500 non-null    object
#  5   Date    500 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 23.6+ KB

# %%
df_T1.describe(include='all')
# Out:
#               Num1        Num2        Num3      Name   Name2  \
# count   500.000000  500.000000  500.000000       500     500
# unique  500.000000  500.000000  500.000000        11      11
# top     545.521388   99.483191  958.883378  Naquibah  Nabila
# freq      1.000000    1.000000    1.000000        60      55
# mean           NaN         NaN         NaN       NaN     NaN
# min            NaN         NaN         NaN       NaN     NaN
# 25%            NaN         NaN         NaN       NaN     NaN
# 50%            NaN         NaN         NaN       NaN     NaN
# 75%            NaN         NaN         NaN       NaN     NaN
# max            NaN         NaN         NaN       NaN     NaN
#
#                                  Date
# count                             500
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-06-29 17:59:59.999999744
# min               2023-01-01 00:00:00
# 25%               2023-03-22 18:00:00
# 50%               2023-06-30 12:00:00
# 75%               2023-10-03 06:00:00
# max               2023-12-30 00:00:00

# %%
#Changing multiple at once:
df_T1[['Num1','Num2','Num3']] = df_T1[['Num1','Num2','Num3']].astype(float)

df_T1.dtypes #ways to check the datatype
# Out:
# Num1            float64
# Num2            float64
# Num3            float64
# Name             object
# Name2            object
# Date     datetime64[ns]
# dtype: object

# %%
df_T1.describe()
# Out:
#              Num1        Num2        Num3                           Date
# count  500.000000  500.000000  500.000000                            500
# mean   500.377695   99.082016  950.170263  2023-06-29 17:59:59.999999744
# min    438.586242   58.268983  926.081040            2023-01-01 00:00:00
# 25%    486.504897   92.134787  945.250956            2023-03-22 18:00:00
# 50%    501.176824   99.327536  950.182120            2023-06-30 12:00:00
# 75%    513.352733  105.589518  954.791224            2023-10-03 06:00:00
# max    577.913560  129.334943  975.627096            2023-12-30 00:00:00
# std     20.194696   10.509594    7.407033                            NaN

# %%
df_T1.describe(include='all')
# Out:
#               Num1        Num2        Num3      Name   Name2  \
# count   500.000000  500.000000  500.000000       500     500
# unique         NaN         NaN         NaN        11      11
# top            NaN         NaN         NaN  Naquibah  Nabila
# freq           NaN         NaN         NaN        60      55
# mean    500.377695   99.082016  950.170263       NaN     NaN
# min     438.586242   58.268983  926.081040       NaN     NaN
# 25%     486.504897   92.134787  945.250956       NaN     NaN
# 50%     501.176824   99.327536  950.182120       NaN     NaN
# 75%     513.352733  105.589518  954.791224       NaN     NaN
# max     577.913560  129.334943  975.627096       NaN     NaN
# std      20.194696   10.509594    7.407033       NaN     NaN
#
#                                  Date
# count                             500
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-06-29 17:59:59.999999744
# min               2023-01-01 00:00:00
# 25%               2023-03-22 18:00:00
# 50%               2023-06-30 12:00:00
# 75%               2023-10-03 06:00:00
# max               2023-12-30 00:00:00
# std                               NaN

# %% [markdown]
# **Test 2**

# %%
#TEST 2

import pandas as pd
import numpy as np
from datetime import datetime, timedelta

#create numerical data (or numerical column)
#all those column that will be int or float

col7 = np.random.normal(80, 10, 11)
col8 = np.random.normal(75, 15, 11)
col9 = np.random.normal(60, 10, 11)

#create categorical data

categorical_data = ['Amy','Sya','Naquibah','Zura','Abidah','Saras','Nabila','Aisyah','Maryam','Anis','Hikmah']

col10 = np.random.choice(categorical_data, 11)

#create data time

start_data = datetime(2023, 1, 1) # This variable was originally named 'start_data'
end_date = datetime(2024, 1, 1)

# Use 'start_data' instead of 'start_date'
delta = end_date - start_data

date_list = [start_data + timedelta(days=x) for x in range(delta.days)]

col12 = np.random.choice(date_list, 11)

#combine all the columns

data = np.column_stack((col7,col8,col9,col10,col12))

df_T2 = pd.DataFrame(data, columns =['BM','BI','Sejarah','Name','Date'])
df_T2.head(12) # Call the head() method to display the DataFrame
# Out:
#            BM         BI    Sejarah      Name       Date
# 0   89.978854  92.401895  58.127436       Sya 2023-02-20
# 1   86.231948   63.38583  62.273986    Abidah 2023-06-21
# 2   98.286156  83.640856  63.555928    Abidah 2023-12-20
# 3   77.139055  66.590794  77.150889    Maryam 2023-11-29
# 4   81.782889   86.77024  34.031906    Maryam 2023-04-22
# 5   79.934472  38.457714  46.150122       Sya 2023-04-15
# 6   86.997038  86.087735  76.080761    Abidah 2023-08-11
# 7   102.53892  79.426084   60.30765    Aisyah 2023-12-30
# 8   97.094431   82.02479  51.589762    Hikmah 2023-03-07
# 9   73.462272  66.676287  61.125622  Naquibah 2023-09-15
# 10  72.317703  80.618231  45.011721       Amy 2023-08-20

# %%
df_T2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BM       11 non-null     object
#  1   BI       11 non-null     object
#  2   Sejarah  11 non-null     object
#  3   Name     11 non-null     object
#  4   Date     11 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 568.0+ bytes

# %%
#Changing multiple object to float:
df_T2[['BM','BI','Sejarah']] = df_T2[['BM','BI','Sejarah']].astype(float)

df_T2.dtypes #ways to check the datatype
# Out:
# BM                float64
# BI                float64
# Sejarah           float64
# Name               object
# Date       datetime64[ns]
# dtype: object

# %%
df_T2.describe(include='all')
# Out:
#                 BM         BI    Sejarah    Name  \
# count    11.000000  11.000000  11.000000      11
# unique         NaN        NaN        NaN       7
# top            NaN        NaN        NaN  Abidah
# freq           NaN        NaN        NaN       3
# mean     85.978522  75.098223  57.764162     NaN
# min      72.317703  38.457714  34.031906     NaN
# 25%      78.536764  66.633541  48.869942     NaN
# 50%      86.231948  80.618231  60.307650     NaN
# 75%      93.536643  84.864295  62.914957     NaN
# max     102.538920  92.401895  77.150889     NaN
# std      10.207531  15.328371  12.969120     NaN
#
#                                  Date
# count                              11
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-07-25 08:43:38.181818112
# min               2023-02-20 00:00:00
# 25%               2023-04-18 12:00:00
# 50%               2023-08-11 00:00:00
# 75%               2023-10-22 12:00:00
# max               2023-12-30 00:00:00
# std                               NaN

# %% [markdown]
# **Part 2: Matplot Lib**
#
# ---

# %%
from matplotlib import pyplot as plt

x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y)

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1)

plt.show()

# %% [markdown]
# **Part 2.1: How To Add Labels**
#
# ---

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y)

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1)

# Add labels
plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.show()

# %% [markdown]
# **Part 2.2: How To Add Title**
#
# ---

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y)

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1)

#Add labels
plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

#Add title
plt.title('Salary in Kuala Lumpur')

plt.show()

# %% [markdown]
# **Part 2.3: How To Add Legend**
#
# ---

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y)

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B'])

plt.show()

# %% [markdown]
# **Part 2.4: How to Customize The Line**
#
# ---
#
#
# You can change the visual of the line by adding parameter next to it (x, y, 'add parameter here' )

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y,'--')

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1,'--')

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B'])

plt.show()

# %% [markdown]
# **Part 2.4.1: Changing Colour of The Line**
#
# ---
#
#
#
# Adding "k infront of - -" will change the colour of the line to black
# Add the color parameter in the plot code
# plt.plot(x,y, color = 'g') / plt.plot(x,y, color = 'blue')
# 'k' = black, 'r' = red, 'b' = blue, 'g' = green, etc
# 'cyan' , 'pink' , 'skyblue', 'green', 'yellow', etc

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y,'k--')

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1,'--')

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B'])

plt.show()

# %% [markdown]
# **Part 2.4.2: Dash line**
#
# ---
#
#
#
# * Here, 'k--' is a format string. plt.plot(x, y, '--'):
#
# * 'k' specifies the color black (k stands for "black").
# * '--' specifies a dashed line style.
# * So, this command plots the data with a black dashed line.
# * Here, only '--' is provided, which specifies a dashed line style.
#
# * No color is explicitly specified.
# * When the color is not specified, matplotlib uses the default color cycle to automatically assign a color to the plot.
# * This cycle typically includes a set of different colors to distinguish multiple plots.

# %% [markdown]
# **Part 2.4.3: Adding Marker (The Markert (dots) in the line)**
#
# ---

# %%
# Sample data
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]

# Create a plot
plt.plot(x,y, color = 'g', linestyle = '--', marker = 'o')

# Sample data 2
x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]

# Create a plot
plt.plot(x1,y1, color = 'r', linestyle = '--', marker = 'o')

# Add tile and labels
plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B'])

# Show plot
plt.show()

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y, color = 'g', linestyle = '--', marker = 'o')

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1, color = 'r', linestyle = '-', marker = 'o')

x2 = [0,1,2,3,4,5,6,7]
y2 = [2,6,7,8,10,11,13,14]
plt.plot(x2,y2, color = 'b', linestyle = '--', marker = 'o')

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B','Company C'])

plt.show()

# %% [markdown]
# **Part 2.4.4: Changing the thickness of the line**
#
# ---

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y, color = 'g', linestyle = '--', marker = 'o', linewidth = 2)

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1, color = 'r', linestyle = '-', marker = 'o', linewidth = 4)

x2 = [0,1,2,3,4,5,6,7]
y2 = [2,6,7,8,10,11,13,14]
plt.plot(x2,y2, color = 'b', linestyle = '--', marker = 'o', linewidth = 5)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B','Company C'])

plt.show()

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y, color = 'g', linestyle = '--', marker = 'o', linewidth = 2)

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1, color = 'r', linestyle = '-', marker = 'o', linewidth = 1)

x2 = [0,1,2,3,4,5,6,7]
y2 = [2,6,7,8,10,11,13,14]
plt.plot(x2,y2, color = 'b', linestyle = '--', marker = 'o', linewidth = 3)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B','Company C'])

plt.show()

# %% [markdown]
# **Part 2.5: Adding A Grid To The Background**
#
# ---

# %%
# Sample data 1
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]

# Sample data 2
x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]

# Sample data 3
x2 = [0,1,2,3,4,5,6,7]
y2 = [2,6,7,8,10,11,13,14]

# Create plot
plt.plot(x,y, color = 'g', linestyle = '--', marker = 'o', linewidth = 2)
plt.plot(x1,y1, color = 'r', linestyle = '-', marker = 'o', linewidth = 1)
plt.plot(x2,y2, color = 'b', linestyle = '--', marker = 'o', linewidth = 3)

# Create labels and tiltes
plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B','Company C'])

# Add grid
plt.grid()

# Show plot
plt.show()

# %% [markdown]
# * If plt.grid() doesn't work
# * Then add 'True' to the parameter
# * plt.grid(True)

# %%
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y, color = 'g', linestyle = '--', marker = 'o', linewidth = 2)

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1, color = 'r', linestyle = '-', marker = 'o', linewidth = 1)

x2 = [0,1,2,3,4,5,6,7]
y2 = [2,6,7,8,10,11,13,14]
plt.plot(x2,y2, color = 'b', linestyle = '--', marker = 'o', linewidth = 3)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B','Company C'])
plt.grid(True) #Adding 'True' to the parameter

plt.show()

# %% [markdown]
# **Part 2.6: Checking All Available Style in Matplot Library**
#
# ---

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# **Part 2.6.1: Changing the visual style from the list of library**
#
# ---
#
#
#
# plt.style.use('name of style')
# Reset visual: plt.style.use('default')

# %%
plt.style.use('Solarize_Light2')

x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]
plt.plot(x,y, color = 'g', linestyle = '--', marker = 'o', linewidth = 2)

x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1, color = 'r', linestyle = '-', marker = 'o', linewidth = 1)

x2 = [0,1,2,3,4,5,6,7]
y2 = [2,6,7,8,10,11,13,14]
plt.plot(x2,y2, color = 'b', linestyle = '--', marker = 'o', linewidth = 3)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B','Company C'])
plt.grid(True)

plt.show()

# %%
plt.style.use('default') #reset visual

# Sample data 1
x = [1,2,3,4,5,6,7,8]
y = [4,7,9,10,13,15,17,19]

# Sample data 2
x1 = [2,3,5,6,7,8,10,11]
y1 = [3,5,8,11,14,16,18,19]
plt.plot(x1,y1, color = 'r', linestyle = '-', marker = 'o', linewidth = 1)

# Sample data 3
x2 = [0,1,2,3,4,5,6,7]
y2 = [2,6,7,8,10,11,13,14]
plt.plot(x2,y2, color = 'b', linestyle = '--', marker = 'o', linewidth = 3)

# Create plot
plt.plot(x,y, color = 'g', linestyle = '--', marker = 'o', linewidth = 2)
plt.bar(x1,y1)

# Add labels title, grid, and adjusting the size of the visual
plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')
plt.title('Salary in Kuala Lumpur')
plt.legend(['Company A','Company B','Company C'])
plt.grid(True) #Add grid
plt.figure(figsize=(8, 6)) #Adjusting size of visual

# Show plot
plt.show()

# %%
#generate random data
data = np.random.random((5,5))

# Create colorbar
plt.grid(False) #Remove Gird
plt.imshow(data)
plt.colorbar(label='Color Indensity')

# Show plot
plt.show()

# %%
import geopandas as gpd

# Load a world map using GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Create a geographic heatmap
world.plot(column='gdp_md_est', cmap='OrRd', legend=True)

# Add title
plt.title('Geographic Heatmap of GDP')

# show plot
plt.show()
# Out:
# <ipython-input-40-b15f5060f651>:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
